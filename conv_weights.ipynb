# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


import matplotlib.pyplot as plt

# %%
conv = nn.Conv1d(1, 1, 3)
conv.weight.min(), conv.weight.max()
# Out:
# (tensor(-0.2300, grad_fn=<MinBackward1>),
#  tensor(0.5470, grad_fn=<MaxBackward1>))

# %%
x = torch.linspace(-3., 2, 50)
print(x)
y = 0.15 * x**3 + x**2 # + 0.5*x+ 1
y1 = y + torch.randn_like(y) * 0.3

plt.plot(x, y)
plt.plot(x, y1, color='red', linestyle='--')
plt.show()
# Out:
# tensor([-3.0000, -2.8980, -2.7959, -2.6939, -2.5918, -2.4898, -2.3878, -2.2857,
#         -2.1837, -2.0816, -1.9796, -1.8776, -1.7755, -1.6735, -1.5714, -1.4694,
#         -1.3673, -1.2653, -1.1633, -1.0612, -0.9592, -0.8571, -0.7551, -0.6531,
#         -0.5510, -0.4490, -0.3469, -0.2449, -0.1429, -0.0408,  0.0612,  0.1633,
#          0.2653,  0.3673,  0.4694,  0.5714,  0.6735,  0.7755,  0.8776,  0.9796,
#          1.0816,  1.1837,  1.2857,  1.3878,  1.4898,  1.5918,  1.6939,  1.7959,
#          1.8980,  2.0000])
